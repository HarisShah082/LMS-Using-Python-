# %%
from tkinter import *
from tkinter import ttk
from tkinter import messagebox

# %%
root=Tk()
root.title("                                                                                     Learning Management System For UIT")
root.geometry("800x550")
root.resizable(0,0)
root.configure(background='black')
#======================================STUDENT===================================
class LoginBtn:
    def __init__(self,main_loop):
        
        myFrame=Frame(main_loop)
        myFrame.pack()
    
        
        self.Loginbtn=Button(main_loop,text="  Login  ",fg="white",bg="blue",command=self.newWindow)
        #self.Loginbtn.grid(row=5,column=1)
        self.Loginbtn.place(x=380,y=100)
        self.label = Label(main_loop, text="Student", relief='solid', width=20, bg='grey', fg='white', font=("bold", 16))
        self.label.place(x=280, y=50)
        
 
    def newWindow(self):
        self.newwin = Toplevel(root)
        self.newwin.title('LOGIN')
        self.newwin.geometry("400x300") 
    
        self.label = Label(self.newwin, text="USERNAME").place(x=100,y=40)
        
        password=Label(self.newwin,text="PASSWORD").place(x=100,y=60)
        
        self.entry=Entry(self.newwin).place(x=180,y=40)

        self.entry=Entry(self.newwin,show="*").place(x=180,y=60)
        
        self.lbtn=Button(self.newwin,text="login",fg="black",command=self.Loginsuccess).place(x=180,y=100)
        
    def Loginsuccess(self):
        self.logsuccess=Toplevel(root)
        self.logsuccess.title=("LOGIN SUCCESS")
        self.logsuccess.geometry("100x100")
        self.label=Label(self.logsuccess,text="Login Success",fg="green").pack()
        pbtn=Button(self.logsuccess,text="Proceed",fg="white",bg="blue",command=self.Del_Loginsuccess).pack()
        
    def Del_Loginsuccess(self):
        
        if messagebox.askyesno("Message", "Proceed?"):
            self.logsuccess.destroy()
            self.newwin.destroy()
#============================================================================================================== 

#============================STUDENT MENU======================================================================
    
            self.smenu=Toplevel(root)
            self.smenu.title=("STUDENT MENU")
            self.smenu.geometry("800x550")
            self.smenu.configure(background="Black")
            self.label=Label(self.smenu,text="Student Menu",relief='solid', width=20, bg='grey', fg='white', font=("bold", 16))
            self.label.place(x=280, y=50)
#============================================ASSIGNMENT=========================================

            self.label=Label(self.smenu,text="Assignment",relief='solid', width=20, bg='grey', fg='white', font=("bold", 12))
            self.label.place(x=15, y=150)
            
            self.Abtn=Button(self.smenu,text="  Check  ",fg="white",bg="blue",command=self.Assignmentwin).place(x=75,y=200)
        
#============================================CLASS WORK============================================
            self.label=Label(self.smenu,text="Class Work",relief='solid', width=20, bg='grey', fg='white', font=("bold", 12))
            self.label.place(x=210, y=150)
            
            self.CWbtn=Button(self.smenu,text="  Check  ",fg="white",bg="blue",command=self.Cwwin).place(x=275,y=200)
            
#============================================GRADES============================================
            self.label=Label(self.smenu,text="Grades",relief='solid', width=20, bg='grey', fg='white', font=("bold", 12))
            self.label.place(x=405, y=150)
            
            self.Gbtn=Button(self.smenu,text="  Check  ",fg="white",bg="blue",command=self.Grades).place(x=470,y=200)
            
#============================================ATTENDANCE============================================
            self.label=Label(self.smenu,text="Attendance",relief='solid', width=20, bg='grey', fg='white', font=("bold", 12))
            self.label.place(x=600, y=150)
            
            self.Attendbtn=Button(self.smenu,text="  Check  ",fg="white",bg="blue",command=self.Attendance).place(x=660,y=200)

#=============================================TABS FOR STUDENT MENU==================================================

    def Assignmentwin(self):
        
        global assignlabel
        self.assignmentwin=Toplevel(root)
        self.assignmentwin.title=("ASSIGNMENTS")
        self.assignmentwin.geometry("800x550")
        self.assignmentwin.configure(background="Black")
        self.label=Label(self.assignmentwin,text="ASSIGNMENTS",relief='solid', width=20, bg='grey', fg='white', font=("bold", 16))
        self.label.place(x=280, y=50)
            
        self.assignlabel=Label(self.assignmentwin,text="No Assignment Found",relief='solid', width=20, bg='black', fg='white', font=("bold", 12))
        self.label.place(x=300, y=100)
            
    def Cwwin(self):
        
        self.Cwwin=Toplevel(root)
        self.Cwwin.title=("CLASS WORK")
        self.Cwwin.geometry("800x550")
        self.Cwwin.configure(background="Black")
        self.label=Label(self.Cwwin,text="Class Work",relief='solid', width=20, bg='grey', fg='white', font=("bold", 16))
        self.label.place(x=280, y=50)
            
        self.label=Label(self.Cwwin,text="No Class Work Found",relief='solid', width=20, bg='black', fg='white', font=("bold", 12))
        self.label.place(x=300, y=100)
            
    def Grades(self):
        
        self.Grades=Toplevel(root)
        self.Grades.title=("GRADES")
        self.Grades.geometry("800x550")
        self.Grades.configure(background="Black")
        self.label=Label(self.Grades,text="GRADES",relief='solid', width=20, bg='grey', fg='white', font=("bold", 16))
        self.label.place(x=280, y=50)
            
        self.label=Label(self.Grades,text="No Grades ",relief='solid', width=20, bg='black', fg='white', font=("bold", 12))
        self.label.place(x=300, y=100)
            
    def Attendance(self):
        
        self.Attendance=Toplevel(root)
        self.Attendance.title=("GRADES")
        self.Attendance.geometry("800x550")
        self.Attendance.configure(background="Black")
        self.label=Label(self.Attendance,text="ATTANDANCE",relief='solid', width=20, bg='grey', fg='white', font=("bold", 16))
        self.label.place(x=280, y=25)
#==========DAYS=================================            
        self.mlabel=Label(self.Attendance,text="Monday",relief='solid', width=15, bg='black', fg='white', font=("bold", 12))
        self.mlabel.place(x=50, y=100)
        self.tlabel=Label(self.Attendance,text="Tuesday",relief='solid', width=15, bg='black', fg='white', font=("bold", 12))
        self.tlabel.place(x=200, y=100)
        self.wlabel=Label(self.Attendance,text="Wednesday",relief='solid', width=15, bg='black', fg='white', font=("bold", 12))
        self.wlabel.place(x=350, y=100)
        self.ttlabel=Label(self.Attendance,text="Thrusday",relief='solid', width=15, bg='black', fg='white', font=("bold", 12))
        self.ttlabel.place(x=500, y=100)
        self.flabel=Label(self.Attendance,text="Friday",relief='solid', width=15, bg='black', fg='white', font=("bold", 12))
        self.flabel.place(x=650, y=100)
#==========WEEK================================= 
        self.mlabel=Label(self.Attendance,text="WEEK 1",relief='solid', bg='black', fg='white', font=("bold", 12))
        self.mlabel.place(x=15, y=150)
        self.tlabel=Label(self.Attendance,text="WEEK 2",relief='solid', bg='black', fg='white', font=("bold", 12))
        self.tlabel.place(x=15, y=200)
        self.wlabel=Label(self.Attendance,text="WEEK 3",relief='solid', bg='black', fg='white', font=("bold", 12))
        self.wlabel.place(x=15, y=250)
        self.ttlabel=Label(self.Attendance,text="WEEK 4",relief='solid', bg='black', fg='white', font=("bold", 12))
        self.ttlabel.place(x=15, y=300)
        self.flabel=Label(self.Attendance,text="WEEK 5",relief='solid',  bg='black', fg='white', font=("bold", 12))
        self.flabel.place(x=15, y=350)
#==============================================================================================================
# def status():
#     username=var_username.get()
#     passcode=var_password.get()
    
#     if username!=('abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'):
#         tkinter.messagebox.showinfo('Message', 'Fill All Inputs')
#     elif passcode!=('abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789'):
#         tkinter.messagebox.showinfo('Message', 'Fill All Inputs')

#==============================================================================================================            

class RegisterBtn:
    def __init__(self,main_loop):
        self.Regbtn=Button(main_loop,text="Register",fg="white",bg="blue",command=self.newWindow)
        #self.Regbtn.grid(row=1,column=2)
        self.Regbtn.place(x=380,y=150)
        
    def newWindow(self):
        self.newwin = Toplevel(root)
        self.newwin.title('LOGIN')
        self.newwin.geometry("400x300") 
    
        self.uname = Label(self.newwin, text="USERNAME")
        self.uname.place(x=100,y=40)
        
        self.password=Label(self.newwin,text="PASSWORD")
        self.password.place(x=100,y=60)
        
        self.entry=Entry(self.newwin).place(x=180,y=40)
        self.entry=Entry(self.newwin,show="*").place(x=180,y=60)
        
        self.rbtn=Button(self.newwin,text="Register",fg="black",command=self.Regsuccess).place(x=180,y=100)
        
    def Regsuccess(self):

        self.regsuccess=Toplevel(root)
        self.regsuccess.title=("LOGIN SUCCESS")
        self.regsuccess.geometry("100x100")
        self.label=Label(self.regsuccess,text="Registered Successfully",fg="green").pack()
        self.rpbtn=Button(self.regsuccess,text="Proceed",fg="white",bg="blue",command=self.Del_Regsuccess).pack()
        
    def Del_Regsuccess(self):
        
        if messagebox.askyesno("Message", "Proceed?"):
            self.regsuccess.destroy()
            self.newwin.destroy()
        
#======================================TEACHER===================================
class TLoginBtn:
    
    def __init__(self,main_loop):
        
        self.myFrame=Frame(main_loop)
        
        self.TLoginbtn=Button(main_loop,text="  Login  ",fg="white",bg="blue",command=self.TnewWindow)
        #self.Loginbtn.grid(row=5,column=1)
        self.TLoginbtn.place(x=380,y=250)
        self.label = Label(main_loop, text="Teacher", relief='solid', width=20, bg='grey', fg='white', font=("bold", 16))
        self.label.place(x=280, y=200)
        
    def TnewWindow(self):
        self.tnewwin = Toplevel(root)
        self.tnewwin.title('LOGIN')
        self.tnewwin.geometry("400x300") 
    
        self.tuname = Label(self.tnewwin, text="USERNAME")
        self.tuname.place(x=100,y=40)
        
        self.tpassword=Label(self.tnewwin,text="PASSWORD")
        self.tpassword.place(x=100,y=60)
        
        self.entry=Entry(self.tnewwin).place(x=180,y=40)
        self.entry=Entry(self.tnewwin,show="*").place(x=180,y=60)
        
        self.rbtn=Button(self.tnewwin,text="Login",fg="black",command=self.TLoginsuccess).place(x=180,y=100)
        
    def TLoginsuccess(self):
        self.Tlogsuccess=Toplevel(root)
        self.Tlogsuccess.title=("LOGIN SUCCESS")
        self.Tlogsuccess.geometry("100x100")
        self.Tlabel=Label(self.Tlogsuccess,text="Login Success",fg="green").pack()
        pbtn=Button(self.Tlogsuccess,text="Proceed",fg="white",bg="blue",command=self.Del_TLoginsuccess).pack()
        
    def Del_TLoginsuccess(self):
        
        if messagebox.askyesno("Message", "Proceed?"):
            self.Tlogsuccess.destroy()
            self.tnewwin.destroy()
            
            self.smenu=Toplevel(root)
            self.smenu.title=("STUDENT MENU")
            self.smenu.geometry("800x550")
            self.smenu.configure(background="Black")
            self.label=Label(self.smenu,text="Teacher Menu",relief='solid', width=20, bg='grey', fg='white', font=("bold", 16))
            self.label.place(x=280, y=50)
#=======================================ASSIGNMENT=======================================
            self.label=Label(self.smenu,text="Assignment",relief='solid', width=20, bg='grey', fg='white', font=("bold", 12))
            self.label.place(x=15, y=150)
            
            self.Abtn=Button(self.smenu,text="  ADD  ",fg="white",bg="blue",command=self.windowassignment).place(x=75,y=200)
            
#======================================= CLASS WORK =======================================
            self.label=Label(self.smenu,text="Class Work",relief='solid', width=20, bg='grey', fg='white', font=("bold", 12))
            self.label.place(x=210, y=150)
            
            self.CWbtn=Button(self.smenu,text="  ADD  ",fg="white",bg="blue",command=self.cwwindow).place(x=275,y=200)
            
#=======================================GRADES=======================================
            self.label=Label(self.smenu,text="Grades",relief='solid', width=20, bg='grey', fg='white', font=("bold", 12))
            self.label.place(x=405, y=150)
            
            self.CWbtn=Button(self.smenu,text="  ADD  ",fg="white",bg="blue",command=self.windowgrades).place(x=470,y=200)
            
#=======================================ATTENDANCE=======================================
            self.label=Label(self.smenu,text="Attendance",relief='solid', width=20, bg='grey', fg='white', font=("bold", 12))
            self.label.place(x=600, y=150)
            
            self.CWbtn=Button(self.smenu,text="  ADD  ",fg="white",bg="blue",command=self.TAttendance).place(x=660,y=200)
#============================================Grade TAB FOR TEACHER============================================
    def windowgrades(self):
        
        self.windowgrades=Toplevel(root)
        self.windowgrades.title=("TEACHER MENU")
        self.windowgrades.geometry("800x550")
        self.windowgrades.configure(background="Black")
        self.label=Label(self.windowgrades,text="GRADES",relief='solid', width=20, bg='grey', fg='white', font=("bold", 16))
        self.label.place(x=280, y=50)
        
#====================================================Students ROLL NUMBER================================================================
        self.label=Label(self.windowgrades,text="19B-111-SE",bg="black",fg="white").place(x=15,y=150)
        self.label=Label(self.windowgrades,text="19B-222-SE",bg="black",fg="white").place(x=15,y=180)
        self.label=Label(self.windowgrades,text="19B-333-SE",bg="black",fg="white").place(x=15,y=210)
        self.label=Label(self.windowgrades,text="19B-444-SE",bg="black",fg="white").place(x=15,y=240)
        self.label=Label(self.windowgrades,text="19B-555-SE",bg="black",fg="white").place(x=15,y=270)
        self.label=Label(self.windowgrades,text="19B-666-SE",bg="black",fg="white").place(x=15,y=300)
        self.label=Label(self.windowgrades,text="19B-777-SE",bg="black",fg="white").place(x=15,y=330)
        self.label=Label(self.windowgrades,text="19B-888-SE",bg="black",fg="white").place(x=15,y=360)
        self.label=Label(self.windowgrades,text="19B-999-SE",bg="black",fg="white").place(x=15,y=390)
        self.label=Label(self.windowgrades,text="19B-101-SE",bg="black",fg="white").place(x=15,y=420)
#====================================================Students PASS============================================
        self.label=Label(self.windowgrades,text="PASS",bg="black",fg="green").place(x=115,y=150)
        self.label=Label(self.windowgrades,text="PASS",bg="black",fg="green").place(x=115,y=180)
        self.label=Label(self.windowgrades,text="PASS",bg="black",fg="green").place(x=115,y=210)
        self.label=Label(self.windowgrades,text="PASS",bg="black",fg="green").place(x=115,y=240)
        self.label=Label(self.windowgrades,text="PASS",bg="black",fg="green").place(x=115,y=270)
        self.label=Label(self.windowgrades,text="PASS",bg="black",fg="green").place(x=115,y=300)
        self.label=Label(self.windowgrades,text="PASS",bg="black",fg="green").place(x=115,y=330)
        self.label=Label(self.windowgrades,text="PASS",bg="black",fg="green").place(x=115,y=360)
        self.label=Label(self.windowgrades,text="PASS",bg="black",fg="green").place(x=115,y=390)
        self.label=Label(self.windowgrades,text="PASS",bg="black",fg="green").place(x=115,y=420)
#====================================================Students ROll Number================================================
        self.label=Label(self.windowgrades,text="19B-789-SE",bg="black",fg="white").place(x=165,y=150)
        self.label=Label(self.windowgrades,text="19B-987-SE",bg="black",fg="white").place(x=165,y=180)
        self.label=Label(self.windowgrades,text="19B-456-SE",bg="black",fg="white").place(x=165,y=210)
        self.label=Label(self.windowgrades,text="19B-654-SE",bg="black",fg="white").place(x=165,y=240)
        self.label=Label(self.windowgrades,text="19B-123-SE",bg="black",fg="white").place(x=165,y=270)
        self.label=Label(self.windowgrades,text="19B-321-SE",bg="black",fg="white").place(x=165,y=300)
        self.label=Label(self.windowgrades,text="19B-147-SE",bg="black",fg="white").place(x=165,y=330)
        self.label=Label(self.windowgrades,text="19B-741-SE",bg="black",fg="white").place(x=165,y=360)
        self.label=Label(self.windowgrades,text="19B-258-SE",bg="black",fg="white").place(x=165,y=390)
        self.label=Label(self.windowgrades,text="19B-852-SE",bg="black",fg="white").place(x=165,y=420)
#====================================================Students FAIL============================================
        self.label=Label(self.windowgrades,text="FAIL",bg="black",fg="red").place(x=265,y=150)
        self.label=Label(self.windowgrades,text="FAIL",bg="black",fg="red").place(x=265,y=180)
        self.label=Label(self.windowgrades,text="FAIL",bg="black",fg="red").place(x=265,y=210)
        self.label=Label(self.windowgrades,text="FAIL",bg="black",fg="red").place(x=265,y=240)
        self.label=Label(self.windowgrades,text="FAIL",bg="black",fg="red").place(x=265,y=270)
        self.label=Label(self.windowgrades,text="FAIL",bg="black",fg="red").place(x=265,y=300)
        self.label=Label(self.windowgrades,text="FAIL",bg="black",fg="red").place(x=265,y=330)
        self.label=Label(self.windowgrades,text="FAIL",bg="black",fg="red").place(x=265,y=360)
        self.label=Label(self.windowgrades,text="FAIL",bg="black",fg="red").place(x=265,y=390)
        self.label=Label(self.windowgrades,text="FAIL",bg="black",fg="red").place(x=265,y=420)

#============================================ASSIGNMENT TAB FOR TEACHER============================================


    def windowassignment(self):
        self.windowassignment=Toplevel(root)
        self.windowassignment.title=("TEACHER MENU")
        self.windowassignment.geometry("800x550")
        self.windowassignment.configure(background="Black")
        self.label=Label(self.windowassignment,text="Assignment",relief='solid', width=20, bg='grey', fg='white', font=("bold", 16))
        self.label.place(x=280, y=50)
        
        self.setabtn=Button(self.windowassignment,text="SET" ,fg="white",bg="blue",command=self.Setassignment).place(x=660,y=100)
        self.setabtn=Button(self.windowassignment,text="SET" ,fg="white",bg="blue",command=self.Setassignment2).place(x=660,y=150)
        self.setabtn=Button(self.windowassignment,text="SET" ,fg="white",bg="blue",command=self.Setassignment3).place(x=660,y=200)
        self.setabtn=Button(self.windowassignment,text="SET" ,fg="white",bg="blue",command=self.Setassignment4).place(x=660,y=250)
        self.setabtn=Button(self.windowassignment,text="SET" ,fg="white",bg="blue",command=self.Setassignment5).place(x=660,y=300)

#===================================================================================================================

    def Setassignment(self):
        self.label=Label(self.windowassignment,text="Assignment Week 1",width=20,bg="black",fg="white",font=(14)).place(x=50,y=100)
    def Setassignment2(self):
        self.label=Label(self.windowassignment,text="Assignment Week 2",width=20,bg="black",fg="white",font=(14)).place(x=50,y=150)
    def Setassignment3(self):
        self.label=Label(self.windowassignment,text="Assignment Week 3",width=20,bg="black",fg="white",font=(14)).place(x=50,y=200)
    def Setassignment4(self):
        self.label=Label(self.windowassignment,text="Assignment Week 4",width=20,bg="black",fg="white",font=(14)).place(x=50,y=250)
    def Setassignment5(self):
        self.label=Label(self.windowassignment,text="Assignment Week 5",width=20,bg="black",fg="white",font=(14)).place(x=50,y=300)
#=========================================================================#=========================================================================
    def cwwindow(self):
        self.cwwindow=Toplevel(root)
        self.cwwindow.title=("TEACHER MENU")
        self.cwwindow.geometry("800x550")
        self.cwwindow.configure(background="Black")
        self.label=Label(self.cwwindow,text="Class Work",relief='solid', width=20, bg='grey', fg='white', font=("bold", 16))
        self.label.place(x=280, y=50)
        

        self.setabtn=Button(self.cwwindow,text="SET" ,fg="white",bg="blue",command=self.Setcw).place(x=660,y=100)
        self.setabtn=Button(self.cwwindow,text="SET" ,fg="white",bg="blue",command=self.Setcw2).place(x=660,y=150)
        self.setabtn=Button(self.cwwindow,text="SET" ,fg="white",bg="blue",command=self.Setcw3).place(x=660,y=200)
        self.setabtn=Button(self.cwwindow,text="SET" ,fg="white",bg="blue",command=self.Setcw4).place(x=660,y=250)
        self.setabtn=Button(self.cwwindow,text="SET" ,fg="white",bg="blue",command=self.Setcw5).place(x=660,y=300)
#==============================================================================================================================
    def Setcw(self):
        self.label=Label(self.cwwindow,text="LEACTURE 1",width=20,bg="black",fg="white",font=(14)).place(x=50,y=100)
    def Setcw2(self):
        self.label=Label(self.cwwindow,text="LEACTURE 2",width=20,bg="black",fg="white",font=(14)).place(x=50,y=150)
    def Setcw3(self):
        self.label=Label(self.cwwindow,text="LEACTURE 3",width=20,bg="black",fg="white",font=(14)).place(x=50,y=200)
    def Setcw4(self):
        self.label=Label(self.cwwindow,text="LEACTURE 4",width=20,bg="black",fg="white",font=(14)).place(x=50,y=250)
    def Setcw5(self):
        self.label=Label(self.cwwindow,text="LEACTURE 5",width=20,bg="black",fg="white",font=(14)).place(x=50,y=300)
#========================================================================================================================
   
#=============================================TABS FOR TEACHER ================================================================

    def TAttendance(self):
        
        self.TAttendance=Toplevel(root)
        self.TAttendance.title=("GRADES")
        self.TAttendance.geometry("800x550")
        self.TAttendance.configure(background="Black")
        self.Tlabel=Label(self.TAttendance,text="ATTANDANCE",relief='solid', width=20, bg='black', fg='white', font=("bold", 16))
        self.Tlabel.place(x=280, y=25)
#==========DAYS=================================            
        self.monlabel=Label(self.TAttendance,text="Monday",relief='solid', width=15, bg='black', fg='white', font=("bold", 12))
        self.monlabel.place(x=75, y=100)
        self.tuelabel=Label(self.TAttendance,text="Tuesday",relief='solid', width=15, bg='black', fg='white', font=("bold", 12))
        self.tuelabel.place(x=200, y=100)
        self.wedlabel=Label(self.TAttendance,text="Wednesday",relief='solid', width=15, bg='black', fg='white', font=("bold", 12))
        self.wedlabel.place(x=350, y=100)
        self.thrlabel=Label(self.TAttendance,text="Thrusday",relief='solid', width=15, bg='black', fg='white', font=("bold", 12))
        self.thrlabel.place(x=500, y=100)
        self.frilabel=Label(self.TAttendance,text="Friday",relief='solid', width=15, bg='black', fg='white', font=("bold", 12))
        self.frilabel.place(x=650, y=100)
#==========WEEK================================= 
        self.monlabel=Label(self.TAttendance,text="WEEK 1",relief='solid', bg='black', fg='white', font=("bold", 12))
        self.monlabel.place(x=15, y=150)
        self.tuelabel=Label(self.TAttendance,text="WEEK 2",relief='solid', bg='black', fg='white', font=("bold", 12))
        self.tuelabel.place(x=15, y=200)
        self.wedlabel=Label(self.TAttendance,text="WEEK 3",relief='solid', bg='black', fg='white', font=("bold", 12))
        self.wedlabel.place(x=15, y=250)
        self.thrlabel=Label(self.TAttendance,text="WEEK 4",relief='solid', bg='black', fg='white', font=("bold", 12))
        self.thrlabel.place(x=15, y=300)
        self.frilabel=Label(self.TAttendance,text="WEEK 5",relief='solid',  bg='black', fg='white', font=("bold", 12))
        self.frilabel.place(x=15, y=350)
        
        
#==========================================MARK ATTANDANCE===================================== 
        self.markbtn1=Button(self.TAttendance,text="+",bg="black",fg="white",command=self.Present).place(x=175,y=150)
        self.markbtn2=Button(self.TAttendance,text="-",bg="black",fg="white",command=self.Absent).place (x=195,y=150)
        
        self.markbtn1=Button(self.TAttendance,text="+",bg="black",fg="white",command=self.TuePresent).place(x=300,y=150)
        self.markbtn2=Button(self.TAttendance,text="-",bg="black",fg="white",command=self.TueAbsent).place (x=320,y=150)
        
        self.markbtn1=Button(self.TAttendance,text="+",bg="black",fg="white",command=self.WedPresent).place(x=450,y=150)
        self.markbtn2=Button(self.TAttendance,text="-",bg="black",fg="white",command=self.WedAbsent).place (x=470,y=150)
        
        self.markbtn1=Button(self.TAttendance,text="+",bg="black",fg="white",command=self.ThrPresent).place(x=600,y=150)
        self.markbtn2=Button(self.TAttendance,text="-",bg="black",fg="white",command=self.ThrAbsent).place (x=620,y=150)
        
        self.markbtn1=Button(self.TAttendance,text="+",bg="black",fg="white",command=self.FriPresent).place(x=750,y=150)
        self.markbtn2=Button(self.TAttendance,text="-",bg="black",fg="white",command=self.FriAbsent).place (x=770,y=150)
#==============================================WEEK 2==================================
        
        self.markbtn1=Button(self.TAttendance,text="+",bg="black",fg="white",command=self.w2mPresent).place(x=175,y=200)
        self.markbtn2=Button(self.TAttendance,text="-",bg="black",fg="white",command=self.w2mAbsent).place (x=195,y=200)
        
        self.markbtn1=Button(self.TAttendance,text="+",bg="black",fg="white",command=self.w2TuePresent).place(x=300,y=200)
        self.markbtn2=Button(self.TAttendance,text="-",bg="black",fg="white",command=self.w2TueAbsent).place (x=320,y=200)
        
        self.markbtn1=Button(self.TAttendance,text="+",bg="black",fg="white",command=self.w2WedPresent).place(x=450,y=200)
        self.markbtn2=Button(self.TAttendance,text="-",bg="black",fg="white",command=self.w2WedAbsent).place (x=470,y=200)
        
        self.markbtn1=Button(self.TAttendance,text="+",bg="black",fg="white",command=self.w2ThrPresent).place(x=600,y=200)
        self.markbtn2=Button(self.TAttendance,text="-",bg="black",fg="white",command=self.w2ThrAbsent).place (x=620,y=200)
        
        self.markbtn1=Button(self.TAttendance,text="+",bg="black",fg="white",command=self.w2FriPresent).place(x=750,y=200)
        self.markbtn2=Button(self.TAttendance,text="-",bg="black",fg="white",command=self.w2FriAbsent).place (x=770,y=200)
#==============================================WEEK 3==================================
        self.markbtn1=Button(self.TAttendance,text="+",bg="black",fg="white",command=self.w3mPresent).place(x=175,y=250)
        self.markbtn2=Button(self.TAttendance,text="-",bg="black",fg="white",command=self.w3mAbsent).place (x=195,y=250)
        
        self.markbtn1=Button(self.TAttendance,text="+",bg="black",fg="white",command=self.w3TuePresent).place(x=300,y=250)
        self.markbtn2=Button(self.TAttendance,text="-",bg="black",fg="white",command=self.w3TueAbsent).place (x=320,y=250)
        
        self.markbtn1=Button(self.TAttendance,text="+",bg="black",fg="white",command=self.w3WedPresent).place(x=450,y=250)
        self.markbtn2=Button(self.TAttendance,text="-",bg="black",fg="white",command=self.w3WedAbsent).place (x=470,y=250)
        
        self.markbtn1=Button(self.TAttendance,text="+",bg="black",fg="white",command=self.w3ThrPresent).place(x=600,y=250)
        self.markbtn2=Button(self.TAttendance,text="-",bg="black",fg="white",command=self.w3ThrAbsent).place (x=620,y=250)
        
        self.markbtn1=Button(self.TAttendance,text="+",bg="black",fg="white",command=self.w3FriPresent).place(x=750,y=250)
        self.markbtn2=Button(self.TAttendance,text="-",bg="black",fg="white",command=self.w3FriAbsent).place (x=770,y=250)
#==============================================WEEK 4===================================        
        self.markbtn1=Button(self.TAttendance,text="+",bg="black",fg="white",command=self.w4mPresent).place(x=175,y=300)
        self.markbtn2=Button(self.TAttendance,text="-",bg="black",fg="white",command=self.w4mAbsent).place (x=195,y=300)
        
        self.markbtn1=Button(self.TAttendance,text="+",bg="black",fg="white",command=self.w4TuePresent).place(x=300,y=300)
        self.markbtn2=Button(self.TAttendance,text="-",bg="black",fg="white",command=self.w4TueAbsent).place (x=320,y=300)
        
        self.markbtn1=Button(self.TAttendance,text="+",bg="black",fg="white",command=self.w4WedPresent).place(x=450,y=300)
        self.markbtn2=Button(self.TAttendance,text="-",bg="black",fg="white",command=self.w4WedAbsent).place (x=470,y=300)
        
        self.markbtn1=Button(self.TAttendance,text="+",bg="black",fg="white",command=self.w4ThrPresent).place(x=600,y=300)
        self.markbtn2=Button(self.TAttendance,text="-",bg="black",fg="white",command=self.w4ThrAbsent).place (x=620,y=300)
        
        self.markbtn1=Button(self.TAttendance,text="+",bg="black",fg="white",command=self.w4FriPresent).place(x=750,y=300)
        self.markbtn2=Button(self.TAttendance,text="-",bg="black",fg="white",command=self.w4FriAbsent).place (x=770,y=300)
#==============================================WEEK 5==================================
        self.markbtn1=Button(self.TAttendance,text="+",bg="black",fg="white",command=self.w5mPresent).place(x=175,y=350)
        self.markbtn2=Button(self.TAttendance,text="-",bg="black",fg="white",command=self.w5mAbsent).place (x=195,y=350)
        
        self.markbtn1=Button(self.TAttendance,text="+",bg="black",fg="white",command=self.w5TuePresent).place(x=300,y=350)
        self.markbtn2=Button(self.TAttendance,text="-",bg="black",fg="white",command=self.w5TueAbsent).place (x=320,y=350)
        
        self.markbtn1=Button(self.TAttendance,text="+",bg="black",fg="white",command=self.w5WedPresent).place(x=450,y=350)
        self.markbtn2=Button(self.TAttendance,text="-",bg="black",fg="white",command=self.w5WedAbsent).place (x=470,y=350)
        
        self.markbtn1=Button(self.TAttendance,text="+",bg="black",fg="white",command=self.w5ThrPresent).place(x=600,y=350)
        self.markbtn2=Button(self.TAttendance,text="-",bg="black",fg="white",command=self.w5ThrAbsent).place (x=620,y=350)
        
        self.markbtn1=Button(self.TAttendance,text="+",bg="black",fg="white",command=self.w5FriPresent).place(x=750,y=350)
        self.markbtn2=Button(self.TAttendance,text="-",bg="black",fg="white",command=self.w5FriAbsent).place (x=770,y=350)
#==============================================WEEK 5==================================


#====================================PRESENT and ABSENT Week 1======================================================== 

    def Present(self):
        self.label=Label(self.TAttendance,text="  P   ",bg="green",fg="white").place(x=125,y=150)
    def Absent(self):
        self.label=Label(self.TAttendance,text="  A  ",bg="red",fg="white").place(x=125,y=150)
        
    def TuePresent(self):
        self.label=Label(self.TAttendance,text="  P   ",bg="green",fg="white").place(x=250,y=150)
    def TueAbsent(self):
        self.label=Label(self.TAttendance,text="  A  ",bg="red",fg="white").place(x=250,y=150)
        
    def WedPresent(self):
        self.label=Label(self.TAttendance,text="  P   ",bg="green",fg="white").place(x=400,y=150)
    def WedAbsent(self):
        self.label=Label(self.TAttendance,text="  A  ",bg="red",fg="white").place(x=400,y=150)
        
    def ThrPresent(self):
        self.label=Label(self.TAttendance,text="  P   ",bg="green",fg="white").place(x=550,y=150)
    def ThrAbsent(self):
        self.label=Label(self.TAttendance,text="  A  ",bg="red",fg="white").place(x=550,y=150)
        
    def FriPresent(self):
        self.label=Label(self.TAttendance,text="  P   ",bg="green",fg="white").place(x=700,y=150)
    def FriAbsent(self):
        self.label=Label(self.TAttendance,text="  A  ",bg="red",fg="white").place(x=700,y=150)
#=========================================================================================================================
#====================================PRESENT and ABSENT Week 2======================================================== 

    def w2mPresent(self):
        self.label=Label(self.TAttendance,text="  P   ",bg="green",fg="white").place(x=125,y=200)
    def w2mAbsent(self):
        self.label=Label(self.TAttendance,text="  A  ",bg="red",fg="white").place(x=125,y=200)
        
    def w2TuePresent(self):
        self.label=Label(self.TAttendance,text="  P   ",bg="green",fg="white").place(x=250,y=200)
    def w2TueAbsent(self):
        self.label=Label(self.TAttendance,text="  A  ",bg="red",fg="white").place(x=250,y=200)
        
    def w2WedPresent(self):
        self.label=Label(self.TAttendance,text="  P   ",bg="green",fg="white").place(x=400,y=200)
    def w2WedAbsent(self):
        self.label=Label(self.TAttendance,text="  A  ",bg="red",fg="white").place(x=400,y=200)
        
    def w2ThrPresent(self):
        self.label=Label(self.TAttendance,text="  P   ",bg="green",fg="white").place(x=550,y=200)
    def w2ThrAbsent(self):
        self.label=Label(self.TAttendance,text="  A  ",bg="red",fg="white").place(x=550,y=200)
        
    def w2FriPresent(self):
        self.label=Label(self.TAttendance,text="  P   ",bg="green",fg="white").place(x=700,y=200)
    def w2FriAbsent(self):
        self.label=Label(self.TAttendance,text="  A  ",bg="red",fg="white").place(x=700,y=200)
#=========================================================================================================================
#====================================PRESENT and ABSENT Week 3======================================================== 

    def w3mPresent(self):
        self.label=Label(self.TAttendance,text="  P   ",bg="green",fg="white").place(x=125,y=250)
    def w3mAbsent(self):
        self.label=Label(self.TAttendance,text="  A  ",bg="red",fg="white").place(x=125,y=250)
        
    def w3TuePresent(self):
        self.label=Label(self.TAttendance,text="  P   ",bg="green",fg="white").place(x=250,y=250)
    def w3TueAbsent(self):
        self.label=Label(self.TAttendance,text="  A  ",bg="red",fg="white").place(x=250,y=250)
        
    def w3WedPresent(self):
        self.label=Label(self.TAttendance,text="  P   ",bg="green",fg="white").place(x=400,y=250)
    def w3WedAbsent(self):
        self.label=Label(self.TAttendance,text="  A  ",bg="red",fg="white").place(x=400,y=250)
        
    def w3ThrPresent(self):
        self.label=Label(self.TAttendance,text="  P   ",bg="green",fg="white").place(x=550,y=250)
    def w3ThrAbsent(self):
        self.label=Label(self.TAttendance,text="  A  ",bg="red",fg="white").place(x=550,y=250)
        
    def w3FriPresent(self):
        self.label=Label(self.TAttendance,text="  P   ",bg="green",fg="white").place(x=700,y=250)
    def w3FriAbsent(self):
        self.label=Label(self.TAttendance,text="  A  ",bg="red",fg="white").place(x=700,y=250)
#=========================================================================================================================

#====================================PRESENT and ABSENT Week 4 ======================================================== 

    def w4mPresent(self):
        self.label=Label(self.TAttendance,text="  P   ",bg="green",fg="white").place(x=125,y=300)
    def w4mAbsent(self):
        self.label=Label(self.TAttendance,text="  A  ",bg="red",fg="white").place(x=125,y=300)
        
    def w4TuePresent(self):
        self.label=Label(self.TAttendance,text="  P   ",bg="green",fg="white").place(x=250,y=300)
    def w4TueAbsent(self):
        self.label=Label(self.TAttendance,text="  A  ",bg="red",fg="white").place(x=250,y=300)
        
    def w4WedPresent(self):
        self.label=Label(self.TAttendance,text="  P   ",bg="green",fg="white").place(x=400,y=300)
    def w4WedAbsent(self):
        self.label=Label(self.TAttendance,text="  A  ",bg="red",fg="white").place(x=400,y=300)
        
    def w4ThrPresent(self):
        self.label=Label(self.TAttendance,text="  P   ",bg="green",fg="white").place(x=550,y=300)
    def w4ThrAbsent(self):
        self.label=Label(self.TAttendance,text="  A  ",bg="red",fg="white").place(x=550,y=300)
        
    def w4FriPresent(self):
        self.label=Label(self.TAttendance,text="  P   ",bg="green",fg="white").place(x=700,y=300)
    def w4FriAbsent(self):
        self.label=Label(self.TAttendance,text="  A  ",bg="red",fg="white").place(x=700,y=300)
#=========================================================================================================================
#====================================PRESENT and ABSENT Week 5 ======================================================== 

    def w5mPresent(self):
        self.label=Label(self.TAttendance,text="  P   ",bg="green",fg="white").place(x=125,y=350)
    def w5mAbsent(self):
        self.label=Label(self.TAttendance,text="  A  ",bg="red",fg="white").place(x=125,y=350)
        
    def w5TuePresent(self):
        self.label=Label(self.TAttendance,text="  P   ",bg="green",fg="white").place(x=250,y=350)
    def w5TueAbsent(self):
        self.label=Label(self.TAttendance,text="  A  ",bg="red",fg="white").place(x=250,y=350)
        
    def w5WedPresent(self):
        self.label=Label(self.TAttendance,text="  P   ",bg="green",fg="white").place(x=400,y=350)
    def w5WedAbsent(self):
        self.label=Label(self.TAttendance,text="  A  ",bg="red",fg="white").place(x=400,y=350)
        
    def w5ThrPresent(self):
        self.label=Label(self.TAttendance,text="  P   ",bg="green",fg="white").place(x=550,y=350)
    def w5ThrAbsent(self):
        self.label=Label(self.TAttendance,text="  A  ",bg="red",fg="white").place(x=550,y=350)
        
    def w5FriPresent(self):
        self.label=Label(self.TAttendance,text="  P   ",bg="green",fg="white").place(x=700,y=350)
    def w5FriAbsent(self):
        self.label=Label(self.TAttendance,text="  A  ",bg="red",fg="white").place(x=700,y=350)
#=========================================================================================================================
#=============================================REGISTER BUTTON FOR TEACHER ================================================================
class TRegisterBtn:
    def __init__(self,main_loop):
        self.TRegbtn=Button(main_loop,text="Register",fg="white",bg="blue",command=self.TnewWindow)
        #self.Regbtn.grid(row=1,column=2)
        self.TRegbtn.place(x=380,y=300)
        
    def TnewWindow(self):
        self.tnewwin = Toplevel(root)
        self.tnewwin.title('LOGIN')
        self.tnewwin.geometry("400x300") 
    
        self.tuname = Label(self.tnewwin, text="USERNAME")
        self.tuname.place(x=100,y=40)
        
        self.tpassword=Label(self.tnewwin,text="PASSWORD")
        self.tpassword.place(x=100,y=60)
        
        self.entry=Entry(self.tnewwin).place(x=180,y=40)
        self.entry=Entry(self.tnewwin,show="*").place(x=180,y=60)
        
        self.rbtn=Button(self.tnewwin,text="Register",fg="black",command=self.TRegsuccess).place(x=180,y=100)
        
        
    def TRegsuccess(self):

        self.Tregsuccess=Toplevel(root)
        self.Tregsuccess.title=("LOGIN SUCCESS")
        self.Tregsuccess.geometry("100x100")
        self.label=Label(self.Tregsuccess,text="Registered Successfully",fg="green").pack()
        self.rpbtn=Button(self.Tregsuccess,text="Proceed",fg="white",bg="blue",command=self.Del_TRegsuccess).pack()
        
    def Del_TRegsuccess(self):
        
        if messagebox.askyesno("Message", "Proceed?"):
            self.Tregsuccess.destroy()
            self.tnewwin.destroy()

#=========================================================================




logbtn=LoginBtn(root)
regbtn=RegisterBtn(root)
tlogbtn=TLoginBtn(root)
tregbtn=TRegisterBtn(root)

root.mainloop()
